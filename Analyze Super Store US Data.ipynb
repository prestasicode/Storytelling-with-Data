# %% [markdown]
# ## Analyzing using data P1-SuperStoreUS-2015 that have 25 features which is:
# Row ID
# Order Priority
# Discount
# Unit Price
# Shipping Cost
# Customer ID
# Customer Name
# Ship Mode
# Customer Segment
# Product Category
# Product Sub-Category
# Product Container
# Product Name
# Product Base Margin
# Country
# Region
# State or Province
# City
# Postal Code
# Order Date
# Ship Date
# Profit
# Quantity ordered new
# Sales
# Order ID

# %%
import pandas as pd
dataset = pd.read_excel("P1-SuperStoreUS-2015.xlsx")
dataset.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                1952 non-null   int64
#  1   Order Priority        1952 non-null   object
#  2   Discount              1952 non-null   float64
#  3   Unit Price            1952 non-null   float64
#  4   Shipping Cost         1952 non-null   float64
#  5   Customer ID           1952 non-null   int64
#  6   Customer Name         1952 non-null   object
#  7   Ship Mode             1952 non-null   object
#  8   Customer Segment      1952 non-null   object
#  9   Product Category      1952 non-null   object
#  10  Product Sub-Category  1952 non-null   object
#  11  Product Container     1952 non-null   object
#  12  Product Name          1952 non-null   object
#  13  Product Base Margin   1936 non-null   float64
#  14  Country               1952 non-null   object
# ...

# %%
dataset.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   1952.000000  1952.000000  1952.000000    1952.000000  1952.000000
# mean   19916.479508     0.048975   109.079221      12.968151  1735.376537
# std     5957.595627     0.031378   393.481301      17.414631   991.078006
# min       64.000000     0.000000     1.140000       0.490000     3.000000
# 25%    19121.000000     0.020000     6.480000       3.230000   875.000000
# 50%    21164.500000     0.050000    20.990000       6.150000  1738.000000
# 75%    23483.250000     0.080000   100.972500      14.362500  2578.250000
# max    26389.000000     0.210000  6783.020000     164.730000  3403.000000
#
#        Product Base Margin   Postal Code        Profit  Quantity ordered new  \
# count          1936.000000   1952.000000   1952.000000           1952.000000
# mean              0.515186  51534.769467    114.793859             12.944672
# ...

# %% [markdown]
# # Who were the Customer Region on the Super Store US?
# Let's look at some demographical information about the customer.

# %%
#Creating a factorplot, charting the number of male and female passengers
import seaborn as sns
sns.factorplot('Region',data=dataset,kind='count')
# Out:
# C:\Users\PERSONAL\anaconda3\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot('Profit',data=dataset,hue='Region',kind='count')

# %%
dataset[['Profit','Sales']].plot(subplots=False,figsize=(20,10))

# %%
dataset2 = dataset[['Order Date','Profit']]
dataset2.head()
# Out:
#   Order Date     Profit
# 0 2015-01-07     4.5600
# 1 2015-06-13  4390.3665
# 2 2015-02-15   -53.8096
# 3 2015-05-12   803.4705
# 4 2015-05-12   -24.0300

# %%
import pandas as pd
dataset3 = pd.read_excel("P1-SuperStoreUS-2015.xlsx", index_col=19)
dataset3.head()
# Out:
#             Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# Order Date
# 2015-01-07   20847           High      0.01        2.84           0.93
# 2015-06-13   20228  Not Specified      0.02      500.98          26.00
# 2015-02-15   21776       Critical      0.06        9.48           7.29
# 2015-05-12   24844         Medium      0.09       78.69          19.99
# 2015-05-12   24846         Medium      0.08        3.28           2.31
#
#             Customer ID      Customer Name       Ship Mode Customer Segment  \
# Order Date
# 2015-01-07            3      Bonnie Potter     Express Air        Corporate
# 2015-06-13            5     Ronnie Proctor  Delivery Truck      Home Office
# 2015-02-15           11      Marcus Dunlap     Regular Air      Home Office
# 2015-05-12           14  Gwendolyn F Tyson     Regular Air   Small Business
# 2015-05-12           14  Gwendolyn F Tyson     Regular Air   Small Business
#
# ...

# %%
dataset3['Profit'].plot(subplots=False,figsize=(20,10))

# %%
import pandas as pd
dataset4 = pd.read_excel("P1-SuperStoreUS-2015.xlsx", index_col=10)
dataset4.head()
# Out:
#                       Row ID Order Priority  Discount  Unit Price  \
# Product Sub-Category
# Pens & Art Supplies    20847           High      0.01        2.84
# Chairs & Chairmats     20228  Not Specified      0.02      500.98
# Office Furnishings     21776       Critical      0.06        9.48
# Office Furnishings     24844         Medium      0.09       78.69
# Pens & Art Supplies    24846         Medium      0.08        3.28
#
#                       Shipping Cost  Customer ID      Customer Name  \
# Product Sub-Category
# Pens & Art Supplies            0.93            3      Bonnie Potter
# Chairs & Chairmats            26.00            5     Ronnie Proctor
# Office Furnishings             7.29           11      Marcus Dunlap
# Office Furnishings            19.99           14  Gwendolyn F Tyson
# Pens & Art Supplies            2.31           14  Gwendolyn F Tyson
#
#                            Ship Mode Customer Segment Product Category  ...  \
# ...

# %%
dataset4['Sales'].plot(legend=True,figsize=(12,5))
